# %% [markdown]
# # 데이터 수집

# %% [markdown]
# ## 1. 카카오맵 api를 통해 키워드별 장소 크롤링

# %%
import json
import requests
# REST 키
headers = {"Authorization": "KakaoAK 7d323e26f84156c6194a9d77f33e1e6a"}
# 파라미터
params = {"query" : "제주도 일도1동 가볼만한 곳", "page" : 1, "size" : 15,"category_group_code" : "AT4"}
url = "https://dapi.kakao.com/v2/local/search/keyword.json"

# GET을 이용하여 획득
res = requests.get(url, headers=headers, params=params)
# Json을 이용하여 해제
doc = json.loads(res.text)
# 200일 경우 정상
res.status_code
# Out:
# 200

# %%
doc
# Out:
# {'documents': [{'address_name': '제주특별자치도 제주시 일도1동 1296-5',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '26560624',
#    'phone': '',
#    'place_name': '칠성로쇼핑거리',
#    'place_url': 'http://place.map.kakao.com/26560624',
#    'road_address_name': '',
#    'x': '126.525442525838',
#    'y': '33.514367050299'},
#   {'address_name': '제주특별자치도 제주시 일도일동 1095-11',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '43687775',
#    'phone': '',
#    'place_name': '남수각하늘길벽화거리',
#    'place_url': 'http://place.map.kakao.com/43687775',
#    'road_address_name': '',
#    'x': '126.52767113563839',
#    'y': '33.510293165658666'},
#   {'address_name': '제주특별자치도 제주시 일도일동 1492-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리 > 먹자골목',
#    'distance': '',
#    'id': '26523226',
#    'phone': '',
#    'place_name': '흑돼지거리',
#    'place_url': 'http://place.map.kakao.com/26523226',
#    'road_address_name': '',
#    'x': '126.526801372381',
#    'y': '33.5154577629059'},
#   {'address_name': '제주특별자치도 제주시 용담일동 2581-4',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 계곡',
#    'distance': '',
#    'id': '1698424203',
#    'phone': '',
#    'place_name': '용연계곡',
#    'place_url': 'http://place.map.kakao.com/1698424203',
#    'road_address_name': '',
#    'x': '126.51443095406',
#    'y': '33.512764627078'},
#   {'address_name': '제주특별자치도 제주시 일도2동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '14521417',
#    'phone': '064-728-4442',
#    'place_name': '두맹이골목',
#    'place_url': 'http://place.map.kakao.com/14521417',
#    'road_address_name': '',
#    'x': '126.535003674377',
#    'y': '33.5121312997886'},
#   {'address_name': '제주특별자치도 제주시 일도2동 1050-1',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리 > 먹자골목',
#    'distance': '',
#    'id': '22529455',
#    'phone': '',
#    'place_name': '국수문화거리',
#    'place_url': 'http://place.map.kakao.com/22529455',
#    'road_address_name': '',
#    'x': '126.529995796923',
#    'y': '33.5067280992727'},
#   {'address_name': '제주특별자치도 제주시 건입동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '26175298',
#    'phone': '',
#    'place_name': '서부두명품횟집거리',
#    'place_url': 'http://place.map.kakao.com/26175298',
#    'road_address_name': '',
#    'x': '126.527561498088',
#    'y': '33.5166038803482'},
#   {'address_name': '제주특별자치도 제주시 건입동 1316-10',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 전망대',
#    'distance': '',
#    'id': '1406565611',
#    'phone': '',
#    'place_name': '산지천 전망대',
#    'place_url': 'http://place.map.kakao.com/1406565611',
#    'road_address_name': '',
#    'x': '126.529865633519',
#    'y': '33.5164683921675'},
#   {'address_name': '제주특별자치도 제주시 용담2동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 드라이브코스',
#    'distance': '',
#    'id': '8013248',
#    'phone': '',
#    'place_name': '용두암해안도로',
#    'place_url': 'http://place.map.kakao.com/8013248',
#    'road_address_name': '',
#    'x': '126.50956060325',
#    'y': '33.5158270736255'},
#   {'address_name': '제주특별자치도 제주시 용담이동 493-6',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 자전거여행',
#    'distance': '',
#    'id': '24325298',
#    'phone': '',
#    'place_name': '용두암 인증센터',
#    'place_url': 'http://place.map.kakao.com/24325298',
#    'road_address_name': '',
#    'x': '126.51107939101122',
#    'y': '33.51524163487379'},
#   {'address_name': '제주특별자치도 제주시 이도일동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 도보여행 > 제주유배길',
#    'distance': '',
#    'id': '18973444',
#    'phone': '',
#    'place_name': '제주유배길 제주성안유배길',
#    'place_url': 'http://place.map.kakao.com/18973444',
#    'road_address_name': '',
#    'x': '126.5252903700613',
#    'y': '33.512271171475675'},
#   {'address_name': '제주특별자치도 제주시 용담1동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '26245293',
#    'phone': '',
#    'place_name': '제주서문가구거리',
#    'place_url': 'http://place.map.kakao.com/26245293',
#    'road_address_name': '',
#    'x': '126.51782393307',
#    'y': '33.5117122004366'},
#   {'address_name': '제주특별자치도 제주시 건입동',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 드라이브코스',
#    'distance': '',
#    'id': '12706184',
#    'phone': '',
#    'place_name': '중인문로',
#    'place_url': 'http://place.map.kakao.com/12706184',
#    'road_address_name': '',
#    'x': '126.528996693582',
#    'y': '33.5155346502924'},
#   {'address_name': '제주특별자치도 제주시 삼도일동 585-30',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 테마거리',
#    'distance': '',
#    'id': '295036758',
#    'phone': '',
#    'place_name': '전농로왕벚꽃거리',
#    'place_url': 'http://place.map.kakao.com/295036758',
#    'road_address_name': '',
#    'x': '126.515812059181',
#    'y': '33.5044186001404'},
#   {'address_name': '제주특별자치도 제주시 용담삼동 1006-3',
#    'category_group_code': 'AT4',
#    'category_group_name': '관광명소',
#    'category_name': '여행 > 관광,명소 > 온천',
#    'distance': '',
#    'id': '8030782',
#    'phone': '064-742-7000',
#    'place_name': '용두암해수랜드',
#    'place_url': 'http://place.map.kakao.com/8030782',
#    'road_address_name': '제주특별자치도 제주시 서해안로 630',
#    'x': '126.504396779046',
#    'y': '33.5161202745896'}],
#  'meta': {'is_end': False,
#   'pageable_count': 45,
#   'same_name': {'keyword': '가볼만한 곳',
#    'region': ['제주 제주시 일도일동'],
#    'selected_region': '제주 제주시 일도1동'},
#   'total_count': 125}}

# %%
doc["documents"]
# Out:
# [{'address_name': '제주특별자치도 제주시 일도일동 1492-1',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리 > 먹자골목',
#   'distance': '',
#   'id': '26523226',
#   'phone': '',
#   'place_name': '흑돼지거리',
#   'place_url': 'http://place.map.kakao.com/26523226',
#   'road_address_name': '',
#   'x': '126.526801372381',
#   'y': '33.5154577629059'},
#  {'address_name': '제주특별자치도 제주시 일도1동 1296-5',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리',
#   'distance': '',
#   'id': '26560624',
#   'phone': '',
#   'place_name': '칠성로쇼핑거리',
#   'place_url': 'http://place.map.kakao.com/26560624',
#   'road_address_name': '',
#   'x': '126.525442525838',
#   'y': '33.514367050299'},
#  {'address_name': '제주특별자치도 제주시 일도일동 1095-11',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리',
#   'distance': '',
#   'id': '43687775',
#   'phone': '',
#   'place_name': '남수각하늘길벽화거리',
#   'place_url': 'http://place.map.kakao.com/43687775',
#   'road_address_name': '',
#   'x': '126.52767113563839',
#   'y': '33.510293165658666'}]

# %%
# 반복문을 통해 크롤링 데이터 => 데이터프레임화
import pandas as pd

test_df = pd.DataFrame(doc["documents"][0],index = [0])

for i in range(len(doc["documents"])):
    merge_df = pd.DataFrame(doc["documents"][i],index = [i])
    test_df = pd.concat([test_df,merge_df])


test_df

# %% [markdown]
# ## 2. 평점과 이미지 크롤링

# %%
from selenium import webdriver

driver = webdriver.Chrome("driver/chromedriver") # 크롬 드라이버 경로 지정 
driver.get("http://place.map.kakao.com/12710968") # get 명령으로 접근하고 싶은 주소 지정

# %%
import pandas as pd
img_df = pd.read_excel("Final_pro/JEJU_POIAPI4.xlsx")
img_df.head()
# Out:
#        keyword                 address_name category_group_code  \
# 0         테마파크          제주특별자치도 제주시 연동 1320                 CT1
# 1  테마파크,가볼만한 곳  제주특별자치도 제주시 애월읍 신엄리 2880-12                 AT4
# 2  테마파크,가볼만한 곳    제주특별자치도 제주시 애월읍 유수암리 1083                 AT4
# 3  테마파크,가볼만한 곳  제주특별자치도 제주시 애월읍 어음리 산 131-3                 AT4
# 4  테마파크,가볼만한 곳     제주특별자치도 제주시 애월읍 광령리 2698                 AT4
#
#   category_group_name       category_name  distance          id         phone  \
# 0                문화시설  문화,예술 > 문화시설 > 박물관       NaN    26388484  064-742-3700
# 1                관광명소   여행 > 관광,명소 > 테마파크       NaN  1129394481  064-748-4245
# 2                관광명소   여행 > 관광,명소 > 테마파크       NaN   891104398  064-799-6996
# 3                관광명소   여행 > 관광,명소 > 테마파크       NaN  1868828759     1833-9810
# 4                관광명소   여행 > 관광,명소 > 테마파크       NaN     9401924  064-746-3060
#
#        place_name                              place_url  \
# 0  수목원테마파크 아이스뮤지엄    http://place.map.kakao.com/26388484
# 1           고스트타운  http://place.map.kakao.com/1129394481
# 2          제주불빛정원   http://place.map.kakao.com/891104398
# 3          9.81파크  http://place.map.kakao.com/1868828759
# 4          제주공룡랜드     http://place.map.kakao.com/9401924
#
#             road_address_name           x          y
# 0          제주특별자치도 제주시 은수길 69  126.488398  33.470777
# 1  제주특별자치도 제주시 애월읍 부룡수길 35-14  126.356936  33.476195
# 2    제주특별자치도 제주시 애월읍 평화로 2346  126.409179  33.422294
# 3  제주특별자치도 제주시 애월읍 천덕로 880-24  126.366664  33.390290
# 4    제주특별자치도 제주시 애월읍 광령평화2길 1  126.433869  33.441255

# %%
img_df["rating"] = ""
img_df["img_link"] = ""

# %%
import matplotlib.pyplot as plt

# %%
import time
for idx,i in img_df.iterrows():
    time.sleep(0.7)
    driver = webdriver.Chrome("driver/chromedriver") # 크롬 드라이버 경로 지정 
    url = i["place_url"]
    driver.implicitly_wait(8)
    driver.get(url)
    contents = driver.find_element_by_css_selector("#mArticle > div.cont_essential > div:nth-child(1) > div.place_details > div > div > a:nth-child(3) > span.color_b")
    rating = contents.text
    img_df["rating"][idx] = rating

    try:
        image = driver.find_element_by_css_selector("#mArticle > div.cont_photo > div.photo_area > ul > li.size_l > a")
        
    except:
        name = str(idx) + "_" + i["place_name"]
        plt.savefig(f"Final_pro/error/idx_{name}.png")
        driver.quit()

    else:
        img_link = image.get_attribute("style")[23:-3]
        img_link = "https:" + img_link
        img_df["img_link"][idx] = img_link

        response = requests.get(img_df["img_link"][idx])
        name = str(idx) + "_" + i["place_name"]
        with open("Final_pro/img/{}.jpg".format(name), "wb") as f:
            f.write(response.content)
        driver.quit()
# Out:
# C:\Users\alal8\AppData\Local\Temp/ipykernel_2604/3975563189.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   img_df["rating"][idx] = rating
# C:\Users\alal8\AppData\Local\Temp/ipykernel_2604/3975563189.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   img_df["img_link"][idx] = img_link
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2604/3975563189.py in <module>
#       6     driver.implicitly_wait(10)
#       7     driver.get(url)
# ----> 8     contents = driver.find_element_by_css_selector("#mArticle > div.cont_essential > div:nth-child(1) > div.place_details > div > div > a:nth-child(3) > span.color_b")
#       9     rating = contents.text
#      10     img_df["rating"][idx] = rating
#
# ~\miniconda3\envs\ds_study\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\miniconda3\envs\ds_study\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\miniconda3\envs\ds_study\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~\miniconda3\envs\ds_study\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~\miniconda3\envs\ds_study\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\miniconda3\envs\ds_study\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\miniconda3\envs\ds_study\lib\http\client.py in getresponse(self)
#    1346         try:
#    1347             try:
# -> 1348                 response.begin()
#    1349             except ConnectionError:
#    1350                 self.close()
#
# ~\miniconda3\envs\ds_study\lib\http\client.py in begin(self)
#     314         # read until we get a non-100 response
#     315         while True:
# --> 316             version, status, reason = self._read_status()
#     317             if status != CONTINUE:
#     318                 break
#
# ~\miniconda3\envs\ds_study\lib\http\client.py in _read_status(self)
#     275
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#     279             raise LineTooLong("status line")
#
# ~\miniconda3\envs\ds_study\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # 카카오 네비를 이용한 경로 탐색

# %%
URL_base = "https://apis-navi.kakaomobility.com/v1/directions?"
origin = "origin=127.11015314141542,37.39472714688412&"
destination = "destination=127.10824367964793,37.401937080111644&"
waypoints = "waypoints=127.11341936045922,37.39639094915999&"
priority = "priority=RECOMMEND&"
car_type = "car_fuel=GASOLINE&car_hipass=True&summary=True"

URL = URL_base + origin + destination + waypoints + priority + car_type


headers = {"Authorization": "KakaoAK 7d323e26f84156c6194a9d77f33e1e6a"}

# %%
test = requests.get(URL,headers=headers).json()
test

# %%
test["routes"][0]["summary"]["duration"]

# %%
url2 = "https://apis-navi.kakaomobility.com/v1/directions?origin=127.11015314141542,37.39472714688412&destination=127.10824367964793,37.401937080111644&waypoints=&priority=RECOMMEND&car_fuel=GASOLINE&car_hipass=false&alternatives=false&road_details=false"

# %%
all_re = requests.get(url2,headers=headers).json()
all_re

# %%
#경로내 좌표
vertexes = []
for road in all_re['routes'][0]['sections'][0]['roads']:
    test_v = road['vertexes']
    for i in range(0, len(test_v), 2):
        vertexes.append((test_v[i+1], test_v[i]))

# %%
import folium
import pandas as pd

origin = all_re['routes'][0]['summary']['origin']
destination = all_re['routes'][0]['summary']['destination']

map = folium.Map(location=[origin['y'], origin['x']], zoom_start=9)
folium.Marker(location=[origin['y'], origin['x']], popup='origin').add_to(map)
folium.Marker(location=[destination['y'], destination['x']], popup='destination').add_to(map)
folium.PolyLine(vertexes, color='red').add_to(map)
map
